# %%
print("hello world")
# Out:
# hello world

# %%
import torch
import numpy
import transformers
print("PyTorch版本:", torch.__version__)
print("NumPy版本:", numpy.__version__)
print("Jupyter 启动成功！")
# Out:
# PyTorch版本: 2.4.0
# NumPy版本: 1.26.4
# Jupyter 启动成功！
