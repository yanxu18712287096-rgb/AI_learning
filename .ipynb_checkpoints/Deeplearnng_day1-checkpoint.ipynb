# %%
print("hello jupyter")
# Out:
# hello jupyter

# %%
import numpy as np
import torch

a = np.array([1,2,3])
b = torch.tensor([4,5,6])

print("numpy:", a)
print("torch:", b)
# Out:
# numpy: [1 2 3]
# torch: tensor([4, 5, 6])
